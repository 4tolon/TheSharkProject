# %% [markdown]
# # TheSharkProject Cleanig Room

# %% [markdown]
# ## EDA - First Aproximation

# %% [markdown]
# <img src="Images/shark.gif" width="300" align="left">

# %% [markdown]
# ### Importing the libraries and loading the data

# %%
import pandas as pd
import sys
from IPython.display import clear_output
from src import cleanning_func as cf

# %% [markdown]
# #### Loading attacks.csv with encoding.

# %%
dfsk = pd.read_csv('data/attacks.csv',encoding = "ISO-8859-1")

# %% [markdown]
# ### Just a look:

# %%
dfsk.sample(10)
# Out:
#       Case Number         Date    Year        Type    Country  \
# 24471         NaN          NaN     NaN         NaN        NaN
# 25265         NaN          NaN     NaN         NaN        NaN
# 25042         NaN          NaN     NaN         NaN        NaN
# 21966         NaN          NaN     NaN         NaN        NaN
# 1291   2008.02.06  06-Feb-2008  2008.0  Unprovoked        USA
# 10948         NaN          NaN     NaN         NaN        NaN
# 7817            0          NaN     NaN         NaN        NaN
# 5483   1906.01.28  28-Jan-1906  1906.0  Unprovoked  AUSTRALIA
# 19313         NaN          NaN     NaN         NaN        NaN
# 25254         NaN          NaN     NaN         NaN        NaN
#
#                   Area                                         Location  \
# 24471              NaN                                              NaN
# 25265              NaN                                              NaN
# ...

# %% [markdown]
# #### A random sample show us lots of gaps in our data, let's see the size of the dataframe. How many rows and columns we have?

# %%
print(dfsk.shape)
# Out:
# (25723, 24)

# %% [markdown]
# #### An other point of view,  number of columns, Columns names, non - null and Dtype.

# %%
dfsk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %% [markdown]
# #### Here is where a magic function has born....

# %% [markdown]
# # RAS_the_one_and_only_one_cell_output_analisys_program(your_df)

# %% [markdown]
# #### I invite you to try it, and to see the code in /scr of this repo. I could continue improve it, if there is cuorum I will, but I'm on a mission  to solve the global infestation of sharks attacks of a dataframe. I put a reminder postit in the entrance of this worm hole.

# %%
new_df = cf.RAS_the_one_and_only_one_cell_output_analisys_program(dfsk)
# Out:
# -----------SOME DATA TO HELP-----------
# Column index   : 1 of 24
# Number of rows : 25723
# Number nam/nul : 19421 thats the 75.5 %
# Example unique : ['25-Jun-2018' '18-Jun-2018' '09-Jun-2018']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2124/984646917.py in <module>
# ----> 1 new_df = cf.RAS_the_one_and_only_one_cell_output_analisys_program(dfsk)
#
# ~/Proyectos/ironhack/project/TheSharkProject/src/cleanning_func.py in RAS_the_one_and_only_one_cell_output_analisys_program(data)
#      37         #print(f'Number uniques : {len(uniq)} some of them are: {uniq_show}')
#      38         # Input stament
# ---> 39         b = (input(f"Enter a new value:\nor skip to next by pressing enter\ntype 'del' to show next function to drop this column\n\n\n\n\b'{a[i]}'"))
#      40         # Loops for mange the unmodified and refreshing the output
# ...

# %%
new_df
